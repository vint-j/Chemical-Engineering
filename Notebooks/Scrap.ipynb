# %%
import numpy as np

p1sat = np.exp(13.8858 - (2788.51 / (100+ 220.79)))
p2sat = np.exp(14.0045 - (3279.47 / (100+ 213.20)))
print(0.4*(101.01) + 0.6*(16.77))
print(p1sat, p2sat)
# Out:
# 50.466
# 180.03768493352766 34.24877173887707
